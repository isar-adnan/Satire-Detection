# %%
plot1 = [5,3]
plot2 = [data1.Pos_Sentiment, data1.Neg_Sentiment]
#plot2 = [7,8]

# %%
from math import sqrt
euclidean_distance = sqrt((plot1[0] - plot2[0])**2 + (plot1[1] - plot2[1])**2)
print(euclidean_distance)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-3c6dc00201df> in <module>
#       1 from math import sqrt
# ----> 2 euclidean_distance = sqrt((plot1[0] - plot2[0])**2 + (plot1[1] - plot2[1])**2)
#       3 print(euclidean_distance)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'float'>

# %%
import pandas as pd
data1 = pd.read_csv("./satire-dataset.csv")

print(data1.columns.values)
# Out:
# ['Pos_Sentiment' 'Neg_Sentiment' 'Polarity' 'Type']

# %%
L1 = [8,3]
L2 = [data1.Pos_Sentiment, data1.Neg_Sentiment]

# %%
df = pd.DataFrame(data1)

# %%
df['distance'] = np.linalg.norm(df[['Pos_Sentiment', 'Neg_Sentiment']].sub(np.array(L1)), axis=1)

# %%
df
# Out:
#       Pos_Sentiment  Neg_Sentiment  Polarity    Type   distance
# 0                17              5        12    TRUE   9.219544
# 1                 1              3        -2    TRUE   7.000000
# 2                 6              0         6    TRUE   3.605551
# 3                 5              1         4    TRUE   3.605551
# 4                 2             10        -8    TRUE   9.219544
# 5                 0              0         0    TRUE   8.544004
# 6                 0              4        -4    TRUE   8.062258
# 7                 2              1         1    TRUE   6.324555
# 8                15             20        -5    TRUE  18.384776
# 9                 3              2         1    TRUE   5.099020
# 10               25              9        16    TRUE  18.027756
# 11                3              5        -2    TRUE   5.385165
# 12                0              0         0    TRUE   8.544004
# 13                4              6        -2    TRUE   5.000000
# ...

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import sklearn
import math
data1 = pd.read_csv("./satire-dataset.csv")

# %%
print(data1.columns.values)
# Out:
# ['Pos_Sentiment' 'Neg_Sentiment' 'Polarity' 'Type']

# %%
data1.shape
# Out:
# (4233, 4)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4233 entries, 0 to 4232
# Data columns (total 4 columns):
# Pos_Sentiment    4233 non-null int64
# Neg_Sentiment    4233 non-null int64
# Polarity         4233 non-null int64
# Type             4233 non-null object
# dtypes: int64(3), object(1)
# memory usage: 132.4+ KB

# %%
data1.head()
# Out:
#    Pos_Sentiment  Neg_Sentiment  Polarity  Type
# 0             17              5        12  TRUE
# 1              1              3        -2  TRUE
# 2              6              0         6  TRUE
# 3              5              1         4  TRUE
# 4              2             10        -8  TRUE

# %%
L1 = [8,3]
L2 = [data1.Pos_Sentiment, data1.Neg_Sentiment]

# %%
df = pd.DataFrame(data1)

# %%
df['distance'] = np.linalg.norm(df[['Pos_Sentiment', 'Neg_Sentiment']].sub(np.array(L1)), axis=1)

# %%
df.sort_values(by=['distance'])
# Out:
#       Pos_Sentiment  Neg_Sentiment  Polarity    Type   distance
# 3257              8              3         5    TRUE   0.000000
# 4112              8              3         5    TRUE   0.000000
# 3534              8              3         5  satire   0.000000
# 963               8              3         5    TRUE   0.000000
# 3576              8              3         5    TRUE   0.000000
# 2024              8              3         5    TRUE   0.000000
# 3760              8              3         5    TRUE   0.000000
# 3255              8              3         5    TRUE   0.000000
# 3254              8              3         5    TRUE   0.000000
# 4161              8              3         5    TRUE   0.000000
# 1033              8              3         5    TRUE   0.000000
# 4194              8              3         5    TRUE   0.000000
# 2289              8              3         5    TRUE   0.000000
# 1665              8              3         5    TRUE   0.000000
# ...
